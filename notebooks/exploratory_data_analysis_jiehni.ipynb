# %% [markdown]
# # Exploratory Data Analysis

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# import data
data = pd.read_csv("/Users/jiehni/monash/ADS2001_GROUPMC3/data/processed/melb_processed.csv")
data.head()
# Out:
#    Air Temp (degrees C)  Apparent Temp (degrees C)  Dew Pt Temp (degrees C)  \
# 0                  24.8                        0.0                     14.0
# 1                  24.8                        0.0                     13.3
# 2                  24.9                        0.0                     13.3
# 3                  24.7                        0.0                     13.4
# 4                  24.1                        0.0                     13.3
#
#    Humidity (%)  Wind Speed (km/h)  Wind Gust  (km/h)  MSLP (hPa)  \
# 0          51.0                 11               13.0      1007.4
# 1          48.0                 11               11.0      1007.5
# 2          48.0                 11               13.0      1007.5
# 3          49.0                 11               11.0      1007.4
# 4          51.0                  9                9.0      1007.3
#
#    Rainfall since 9 am (mm)     gamma  Calculated Dew Pt Temp (degrees C)  \
# ...

# %%
# convert datetime variable to datetime
data["Datetime"] = pd.to_datetime(data["Datetime"])

# check variable correlation
data.corr(numeric_only=True)
# Out:
#                                       Air Temp (degrees C)  \
# Air Temp (degrees C)                              1.000000
# Apparent Temp (degrees C)                         0.700922
# Dew Pt Temp (degrees C)                           0.522809
# Humidity (%)                                     -0.636415
# Wind Speed (km/h)                                 0.115222
# Wind Gust  (km/h)                                 0.110149
# MSLP (hPa)                                       -0.036434
# Rainfall since 9 am (mm)                         -0.102453
# gamma                                             0.524878
# Calculated Dew Pt Temp (degrees C)                0.526120
# E (hPa)                                           0.517069
# Calculated Apparent Temp (degrees C)              0.841751
# Rain                                             -0.253642
# day_of_year                                      -0.215529
# hour                                              0.235147
# ...

# %% [markdown]
# As can be seen in the correlation table, humidity (%) and rainfall since 9am (mm) variables have strongest correlation with the target variable rain.

# %%
sns.heatmap(data.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
data.dtypes
# Out:
# Air Temp (degrees C)                           float64
# Apparent Temp (degrees C)                      float64
# Dew Pt Temp (degrees C)                        float64
# Humidity (%)                                   float64
# Wind Speed (km/h)                                int64
# Wind Gust  (km/h)                              float64
# MSLP (hPa)                                     float64
# Rainfall since 9 am (mm)                       float64
# gamma                                          float64
# Calculated Dew Pt Temp (degrees C)             float64
# E (hPa)                                        float64
# Calculated Apparent Temp (degrees C)           float64
# Rain                                             int64
# Datetime                                datetime64[ns]
# day_of_year                                      int64
# hour                                             int64
# month                                            int64
# ...
