# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns;
import pandas as pd

# %%
mel_data = (
    pd.read_excel('Melbourne01.xlsx')
    .rename(columns=lambda col: col.strip())
    .dropna()
)
mel_data.head()
# Out:
#    Year Month  Day  Hour   Min  Air Temp (degrees C)  \
# 0  2011     1  1.0   0.0   4.0                  24.8
# 1  2011     1  1.0   0.0  14.0                  24.8
# 2  2011     1  1.0   0.0  24.0                  24.9
# 3  2011     1  1.0   0.0  34.0                  24.7
# 4  2011     1  1.0   0.0  44.0                  24.1
#
#    Apparent Temp (degrees C)  Dew Pt Temp (degrees C)  Humidity (%)  \
# 0                        0.0                     14.0          51.0
# 1                        0.0                     13.3          48.0
# 2                        0.0                     13.3          48.0
# 3                        0.0                     13.4          49.0
# 4                        0.0                     13.3          51.0
#
#   Wind Direction Wind Speed (km/h)  Wind Gust  (km/h)  MSLP (hPa)  \
# 0             SE                11               13.0      1007.4
# 1             SE                11               11.0      1007.5
# 2             SE                11               13.0      1007.5
# 3             SE                11               11.0      1007.4
# 4            ESE                 9                9.0      1007.3
#
#   Rainfall since 9 am (mm)     gamma  Calculated Dew Pt Temp (degrees C)  \
# 0                        0  0.969609                                14.1
# 1                        0  0.908985                                13.2
# 2                        0  0.915025                                13.2
# 3                        0  0.923560                                13.4
# 4                        0  0.927209                                13.4
#
#      E (hPa)  Calculated Apparent Temp (degrees C)
# 0  15.916676                                  23.9
# 1  14.980401                                  23.6
# 2  15.069879                                  23.7
# 3  15.201624                                  23.6
# 4  15.264860                                  23.4

# %%
numeric_cols = mel_data.columns.drop("Wind Direction")

mel_data[numeric_cols] = mel_data[numeric_cols].apply(
    pd.to_numeric, errors='coerce'
)

mel_data = mel_data.dropna(subset=numeric_cols)

mel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 504500 entries, 0 to 505354
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Year                                  504500 non-null  int64
#  1   Month                                 504500 non-null  int64
#  2   Day                                   504500 non-null  float64
#  3   Hour                                  504500 non-null  float64
#  4   Min                                   504500 non-null  float64
#  5   Air Temp (degrees C)                  504500 non-null  float64
#  6   Apparent Temp (degrees C)             504500 non-null  float64
#  7   Dew Pt Temp (degrees C)               504500 non-null  float64
#  8   Humidity (%)                          504500 non-null  float64
#  9   Wind Direction                        504500 non-null  object
#  10  Wind Speed (km/h)                     504500 non-null  int64
#  11  Wind Gust  (km/h)                     504500 non-null  float64
#  12  MSLP (hPa)                            504500 non-null  float64
#  13  Rainfall since 9 am (mm)              504500 non-null  float64
#  14  gamma                                 504500 non-null  float64
#  15  Calculated Dew Pt Temp (degrees C)    504500 non-null  float64
#  16  E (hPa)                               504500 non-null  float64
#  17  Calculated Apparent Temp (degrees C)  504500 non-null  float64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 73.1+ MB

# %%
mel_data.rename(columns={'Min': 'Minute'}, inplace=True)

mel_data['Datetime'] = pd.to_datetime(
    mel_data[['Year','Month','Day','Hour','Minute']]
)
mel_data.sort_values('Datetime', inplace=True)
mel_data.Datetime.head()
# Out:
# 0   2011-01-01 00:04:00
# 1   2011-01-01 00:14:00
# 2   2011-01-01 00:24:00
# 3   2011-01-01 00:34:00
# 4   2011-01-01 00:44:00
# Name: Datetime, dtype: datetime64[ns]

# %%
temp_cols = ['Air Temp (degrees C)', 'Apparent Temp (degrees C)', 'Calculated Apparent Temp (degrees C)']
for col in temp_cols:
    mel_data = mel_data[(mel_data[col] >= -20) & (mel_data[col] <= 55)]

dew_cols = ['Dew Pt Temp (degrees C)', 'Calculated Dew Pt Temp (degrees C)']
for col in dew_cols:
    mel_data = mel_data[mel_data[col] >= -20]
    mel_data = mel_data[mel_data[col] <= mel_data['Air Temp (degrees C)']]

mel_data = mel_data[(mel_data['Humidity (%)'] >= 0) & (mel_data['Humidity (%)'] <= 100)]

mel_data = mel_data[mel_data['Wind Speed (km/h)'] >= 0]
mel_data = mel_data[(mel_data['Wind Gust  (km/h)'] >= 0) & (mel_data['Wind Gust  (km/h)'] <= 120)]

mel_data = mel_data[(mel_data['MSLP (hPa)'] >= 950) & (mel_data['MSLP (hPa)'] <= 1050)]

mel_data = mel_data[(mel_data['E (hPa)'] >= 5) & (mel_data['E (hPa)'] <= 30)]

mel_data = mel_data[(mel_data['gamma'] >= 0.5) & (mel_data['gamma'] <= 2.5)]

mel_data = mel_data[mel_data['Rainfall since 9 am (mm)'] >= 0]

mel_data["Rain"] = (mel_data["Rainfall since 9 am (mm)"] > 0).astype(int)

# %%
mel_data['Wind Direction'].unique()
# Out:
# array(['SE', 'ESE', 'NE', 'NNE', 'ENE', 'W', 'N', 'SW', 'SSE', 'S', 'SSW',
#        'WSW', 'NW', 'WNW', 'NNW', 'E', 'CALM'], dtype=object)

# %%
mel_data
# Out:
#         Year  Month  Day  Hour  Minute  Air Temp (degrees C)  \
# 0       2011      1  1.0   0.0     4.0                  24.8
# 1       2011      1  1.0   0.0    14.0                  24.8
# 2       2011      1  1.0   0.0    24.0                  24.9
# 3       2011      1  1.0   0.0    34.0                  24.7
# 4       2011      1  1.0   0.0    44.0                  24.1
# ...      ...    ...  ...   ...     ...                   ...
# 505350  2022      3  8.0  15.0    40.0                  18.6
# 505351  2022      3  8.0  15.0    50.0                  18.7
# 505352  2022      3  8.0  16.0     0.0                  18.9
# 505353  2022      3  8.0  16.0    10.0                  19.2
# 505354  2022      3  8.0  16.0    20.0                  19.2
#
#         Apparent Temp (degrees C)  Dew Pt Temp (degrees C)  Humidity (%)  \
# 0                             0.0                     14.0          51.0
# 1                             0.0                     13.3          48.0
# 2                             0.0                     13.3          48.0
# 3                             0.0                     13.4          49.0
# 4                             0.0                     13.3          51.0
# ...                           ...                      ...           ...
# 505350                       16.0                     13.2          71.0
# 505351                       18.5                     13.6          72.0
# 505352                       17.6                     13.7          72.0
# 505353                       18.3                     13.8          71.0
# 505354                       17.5                     13.6          70.0
#
#        Wind Direction  Wind Speed (km/h)  Wind Gust  (km/h)  MSLP (hPa)  \
# 0                  SE                 11               13.0      1007.4
# 1                  SE                 11               11.0      1007.5
# 2                  SE                 11               13.0      1007.5
# 3                  SE                 11               11.0      1007.4
# 4                 ESE                  9                9.0      1007.3
# ...               ...                ...                ...         ...
# 505350            SSW                 39               46.0      1018.0
# 505351            SSW                 35               46.0      1017.9
# 505352            SSW                 35               41.0      1017.8
# 505353              S                 32               35.0      1017.8
# 505354              S                 28               32.0      1017.7
#
#         Rainfall since 9 am (mm)     gamma  \
# 0                            0.0  0.969609
# 1                            0.0  0.908985
# 2                            0.0  0.915025
# 3                            0.0  0.923560
# 4                            0.0  0.927209
# ...                          ...       ...
# 505350                       0.0  0.917431
# 505351                       0.0  0.937732
# 505352                       0.0  0.950348
# 505353                       0.0  0.955250
# 505354                       0.0  0.941066
#
#         Calculated Dew Pt Temp (degrees C)    E (hPa)  \
# 0                                     14.1  15.916676
# 1                                     13.2  14.980401
# 2                                     13.2  15.069879
# 3                                     13.4  15.201624
# 4                                     13.4  15.264860
# ...                                    ...        ...
# 505350                                13.3  15.179146
# 505351                                13.6  15.489394
# 505352                                13.8  15.683896
# 505353                                13.9  15.757716
# 505354                                13.6  15.535776
#
#         Calculated Apparent Temp (degrees C)            Datetime  Rain
# 0                                       23.9 2011-01-01 00:04:00     0
# 1                                       23.6 2011-01-01 00:14:00     0
# 2                                       23.7 2011-01-01 00:24:00     0
# 3                                       23.6 2011-01-01 00:34:00     0
# 4                                       23.4 2011-01-01 00:44:00     0
# ...                                      ...                 ...   ...
# 505350                                  12.0 2022-03-08 15:40:00     0
# 505351                                  13.0 2022-03-08 15:50:00     0
# 505352                                  13.3 2022-03-08 16:00:00     0
# 505353                                  14.2 2022-03-08 16:10:00     0
# 505354                                  14.9 2022-03-08 16:20:00     0
#
# [329647 rows x 20 columns]

# %%
dummies=pd.get_dummies(mel_data['Wind Direction'], prefix='WindDir')
mel_data = mel_data.join(dummies).drop(columns=['Wind Direction'])

# %%
mel_data
# Out:
#         Year  Month  Day  Hour  Minute  Air Temp (degrees C)  \
# 0       2011      1  1.0   0.0     4.0                  24.8
# 1       2011      1  1.0   0.0    14.0                  24.8
# 2       2011      1  1.0   0.0    24.0                  24.9
# 3       2011      1  1.0   0.0    34.0                  24.7
# 4       2011      1  1.0   0.0    44.0                  24.1
# ...      ...    ...  ...   ...     ...                   ...
# 505350  2022      3  8.0  15.0    40.0                  18.6
# 505351  2022      3  8.0  15.0    50.0                  18.7
# 505352  2022      3  8.0  16.0     0.0                  18.9
# 505353  2022      3  8.0  16.0    10.0                  19.2
# 505354  2022      3  8.0  16.0    20.0                  19.2
#
#         Apparent Temp (degrees C)  Dew Pt Temp (degrees C)  Humidity (%)  \
# 0                             0.0                     14.0          51.0
# 1                             0.0                     13.3          48.0
# 2                             0.0                     13.3          48.0
# 3                             0.0                     13.4          49.0
# 4                             0.0                     13.3          51.0
# ...                           ...                      ...           ...
# 505350                       16.0                     13.2          71.0
# 505351                       18.5                     13.6          72.0
# 505352                       17.6                     13.7          72.0
# 505353                       18.3                     13.8          71.0
# 505354                       17.5                     13.6          70.0
#
#         Wind Speed (km/h)  ...  WindDir_NNW  WindDir_NW  WindDir_S  \
# 0                      11  ...        False       False      False
# 1                      11  ...        False       False      False
# 2                      11  ...        False       False      False
# 3                      11  ...        False       False      False
# 4                       9  ...        False       False      False
# ...                   ...  ...          ...         ...        ...
# 505350                 39  ...        False       False      False
# 505351                 35  ...        False       False      False
# 505352                 35  ...        False       False      False
# 505353                 32  ...        False       False       True
# 505354                 28  ...        False       False       True
#
#         WindDir_SE  WindDir_SSE  WindDir_SSW  WindDir_SW WindDir_W  \
# 0             True        False        False       False     False
# 1             True        False        False       False     False
# 2             True        False        False       False     False
# 3             True        False        False       False     False
# 4            False        False        False       False     False
# ...            ...          ...          ...         ...       ...
# 505350       False        False         True       False     False
# 505351       False        False         True       False     False
# 505352       False        False         True       False     False
# 505353       False        False        False       False     False
# 505354       False        False        False       False     False
#
#         WindDir_WNW  WindDir_WSW
# 0             False        False
# 1             False        False
# 2             False        False
# 3             False        False
# 4             False        False
# ...             ...          ...
# 505350        False        False
# 505351        False        False
# 505352        False        False
# 505353        False        False
# 505354        False        False
#
# [329647 rows x 36 columns]

# %%
wind_cols = [c for c in mel_data.columns if c.startswith('WindDir_')]

daily_data = mel_data.resample('D', on='Datetime').agg({
    **{col: 'mean' for col in wind_cols},
    'Air Temp (degrees C)': 'mean',
    'Humidity (%)': 'mean',
    'MSLP (hPa)': 'mean',
    'Wind Speed (km/h)': 'mean',
    'Wind Gust  (km/h)': 'max',
    'E (hPa)': 'mean',
    'Dew Pt Temp (degrees C)': 'mean',
    'Apparent Temp (degrees C)': 'mean',
    'Rainfall since 9 am (mm)': 'sum' 
})
daily_data
# Out:
#             WindDir_CALM  WindDir_E  WindDir_ENE  WindDir_ESE  WindDir_N  \
# Datetime
# 2011-01-01          0.00      0.000     0.038760     0.015504   0.007752
# 2011-01-02          0.00      0.000     0.000000     0.000000   0.000000
# 2011-01-03          0.00      0.000     0.000000     0.000000   0.000000
# 2011-01-04          0.00      0.000     0.000000     0.000000   0.000000
# 2011-01-05          0.00      0.000     0.000000     0.000000   0.000000
# ...                  ...        ...          ...          ...        ...
# 2022-03-04          0.12      0.032     0.016000     0.016000   0.272000
# 2022-03-05          0.00      0.000     0.015038     0.000000   0.007519
# 2022-03-06          0.00      0.000     0.000000     0.000000   0.007692
# 2022-03-07          0.00      0.000     0.000000     0.000000   0.016807
# 2022-03-08          0.00      0.000     0.000000     0.000000   0.000000
#
#             WindDir_NE  WindDir_NNE  WindDir_NNW  WindDir_NW  WindDir_S  ...  \
# Datetime                                                                 ...
# 2011-01-01    0.015504     0.007752     0.000000    0.023256   0.418605  ...
# 2011-01-02    0.000000     0.000000     0.000000    0.000000   0.563380  ...
# 2011-01-03    0.000000     0.000000     0.000000    0.000000   1.000000  ...
# 2011-01-04    0.000000     0.000000     0.008696    0.000000   0.278261  ...
# 2011-01-05    0.000000     0.000000     0.000000    0.007752   0.418605  ...
# ...                ...          ...          ...         ...        ...  ...
# 2022-03-04    0.024000     0.048000     0.064000    0.072000   0.056000  ...
# 2022-03-05    0.022556     0.000000     0.000000    0.007519   0.195489  ...
# 2022-03-06    0.000000     0.000000     0.000000    0.000000   0.000000  ...
# 2022-03-07    0.000000     0.000000     0.000000    0.016807   0.084034  ...
# 2022-03-08    0.000000     0.000000     0.000000    0.000000   0.494382  ...
#
#             WindDir_WSW  Air Temp (degrees C)  Humidity (%)   MSLP (hPa)  \
# Datetime
# 2011-01-01     0.038760             19.651938     61.635659  1011.784496
# 2011-01-02     0.000000             18.560563     53.718310  1015.983099
# 2011-01-03     0.000000             17.300000     51.000000  1016.400000
# 2011-01-04     0.026087             17.183478     59.608696  1012.045217
# 2011-01-05     0.093023             18.110853     66.565891  1010.086047
# ...                 ...                   ...           ...          ...
# 2022-03-04     0.000000             24.486400     66.512000  1009.955200
# 2022-03-05     0.210526             19.320301     89.759398  1007.534586
# 2022-03-06     0.000000             18.484615     79.061538  1015.901538
# 2022-03-07     0.050420             19.169748     72.915966  1015.005042
# 2022-03-08     0.000000             17.624719     75.550562  1017.225843
#
#             Wind Speed (km/h)  Wind Gust  (km/h)    E (hPa)  \
# Datetime
# 2011-01-01          14.325581               43.0  13.980619
# 2011-01-02          22.704225               39.0  11.300188
# 2011-01-03          26.000000               35.0  10.048411
# 2011-01-04          15.782609               37.0  11.574564
# 2011-01-05          19.837209               37.0  13.699222
# ...                       ...                ...        ...
# 2022-03-04          15.688000               46.0  19.023386
# 2022-03-05          19.406015               43.0  20.054762
# 2022-03-06          27.607692               57.0  16.734805
# 2022-03-07          19.016807               37.0  16.132206
# 2022-03-08          30.842697               52.0  15.091738
#
#             Dew Pt Temp (degrees C)  Apparent Temp (degrees C)  \
# Datetime
# 2011-01-01                12.004651                   0.000000
# 2011-01-02                 8.839437                   0.000000
# 2011-01-03                 7.100000                   0.000000
# 2011-01-04                 9.133043                   0.000000
# 2011-01-05                11.719380                   0.000000
# ...                             ...                        ...
# 2022-03-04                16.672800                  25.424800
# 2022-03-05                17.533835                  20.012030
# 2022-03-06                14.642308                  17.083077
# 2022-03-07                14.105882                  18.459664
# 2022-03-08                13.046067                  15.759551
#
#             Rainfall since 9 am (mm)
# Datetime
# 2011-01-01                       0.0
# 2011-01-02                       0.0
# 2011-01-03                       0.0
# 2011-01-04                       0.0
# 2011-01-05                       0.0
# ...                              ...
# 2022-03-04                      20.6
# 2022-03-05                    1349.4
# 2022-03-06                     188.6
# 2022-03-07                       1.4
# 2022-03-08                      90.0
#
# [4085 rows x 26 columns]

# %%
monthly_data = mel_data.resample('ME', on='Datetime').agg({
    **{col: 'mean' for col in wind_cols},
    'Air Temp (degrees C)': 'mean',
    'Humidity (%)': 'mean',
    'MSLP (hPa)': 'mean',
    'Wind Speed (km/h)': 'mean',
    'Wind Gust  (km/h)': 'max',
    'E (hPa)': 'mean',
    'Dew Pt Temp (degrees C)': 'mean',
    'Apparent Temp (degrees C)': 'mean',
    'Rainfall since 9 am (mm)': 'sum'
})
monthly_data
# Out:
#             WindDir_CALM  WindDir_E  WindDir_ENE  WindDir_ESE  WindDir_N  \
# Datetime
# 2011-01-31      0.000000   0.023851     0.022106     0.009889   0.148051
# 2011-02-28      0.000000   0.017241     0.012106     0.022744   0.169112
# 2011-03-31      0.000000   0.004541     0.010055     0.004217   0.262407
# 2011-04-30      0.000000   0.002705     0.006761     0.005747   0.320487
# 2011-05-31      0.000000   0.001542     0.002057     0.005656   0.183548
# ...                  ...        ...          ...          ...        ...
# 2021-11-30      0.012996   0.004566     0.006674     0.002107   0.142255
# 2021-12-31      0.017504   0.003388     0.003670     0.011011   0.127612
# 2022-01-31      0.022211   0.012340     0.015548     0.015548   0.104146
# 2022-02-28      0.021569   0.009804     0.007283     0.010084   0.082913
# 2022-03-31      0.053007   0.030581     0.015291     0.035678   0.074414
#
#             WindDir_NE  WindDir_NNE  WindDir_NNW  WindDir_NW  WindDir_S  ...  \
# Datetime                                                                 ...
# 2011-01-31    0.015707     0.045666     0.025015    0.020070   0.206225  ...
# 2011-02-28    0.011372     0.031548     0.041086    0.033382   0.227439  ...
# 2011-03-31    0.014596     0.044437     0.038923    0.019462   0.159260  ...
# 2011-04-30    0.012508     0.048682     0.051386    0.048005   0.082488  ...
# 2011-05-31    0.001028     0.008740     0.024679    0.041645   0.103342  ...
# ...                ...          ...          ...         ...        ...  ...
# 2021-11-30    0.027749     0.127151     0.009132    0.014050   0.186512  ...
# 2021-12-31    0.015246     0.072840     0.016375    0.022304   0.250988  ...
# 2022-01-31    0.033564     0.100197     0.017522    0.028134   0.202863  ...
# 2022-02-28    0.014566     0.059944     0.012045    0.017087   0.205602  ...
# 2022-03-31    0.025484     0.024465     0.016310    0.035678   0.125382  ...
#
#             WindDir_WSW  Air Temp (degrees C)  Humidity (%)   MSLP (hPa)  \
# Datetime
# 2011-01-31     0.055265             21.447324     64.843805  1011.050553
# 2011-02-28     0.053925             20.933896     67.639032  1014.094497
# 2011-03-31     0.092442             19.213039     65.967888  1015.366591
# 2011-04-30     0.070994             16.358959     68.659567  1022.634990
# 2011-05-31     0.118766             13.321645     77.299229  1018.192596
# ...                 ...                   ...           ...          ...
# 2021-11-30     0.041447             16.789463     71.755181  1014.791113
# 2021-12-31     0.048560             18.740937     63.429983  1014.454433
# 2022-01-31     0.039733             22.901135     64.495558  1012.425642
# 2022-02-28     0.060784             19.994062     63.949300  1015.874706
# 2022-03-31     0.039755             21.212334     75.733945  1012.373802
#
#             Wind Speed (km/h)  Wind Gust  (km/h)    E (hPa)  \
# Datetime
# 2011-01-31          16.987493               63.0  16.389007
# 2011-02-28          15.574101               65.0  16.571908
# 2011-03-31          17.373986               72.0  14.488432
# 2011-04-30          16.574375               56.0  12.379933
# 2011-05-31          14.741902               67.0  11.745212
# ...                       ...                ...        ...
# 2021-11-30          18.714085               82.0  13.284986
# 2021-12-31          19.250423               80.0  13.216647
# 2022-01-31          17.572310               65.0  17.445545
# 2022-02-28          17.399440               72.0  14.689859
# 2022-03-31          17.395515               57.0  18.587416
#
#             Dew Pt Temp (degrees C)  Apparent Temp (degrees C)  \
# Datetime
# 2011-01-31                14.041187                   0.000000
# 2011-02-28                14.316618                   0.000000
# 2011-03-31                12.261953                   0.000000
# 2011-04-30                10.124172                   0.000000
# 2011-05-31                 9.316812                   0.000000
# ...                             ...                        ...
# 2021-11-30                10.980295                  15.214366
# 2021-12-31                10.999520                  17.042377
# 2022-01-31                15.166214                  22.946496
# 2022-02-28                12.521457                  19.073417
# 2022-03-31                16.233435                  21.731397
#
#             Rainfall since 9 am (mm)
# Datetime
# 2011-01-31                    4297.4
# 2011-02-28                    1954.2
# 2011-03-31                    2066.0
# 2011-04-30                    3866.8
# 2011-05-31                    2963.2
# ...                              ...
# 2021-11-30                    5652.2
# 2021-12-31                    1994.2
# 2022-01-31                    6212.4
# 2022-02-28                     334.4
# 2022-03-31                    1913.4
#
# [135 rows x 26 columns]

# %%
plt.figure(figsize=(14,5))
plt.plot(daily_data['Air Temp (degrees C)'])
plt.title('Daily Mean Air Temperature')
plt.ylabel('Temperature (°C)')
plt.xlabel('Date')
plt.show()

plt.figure(figsize=(14,5))
plt.plot(daily_data['Rainfall since 9 am (mm)'])
plt.title('Daily Rainfall')
plt.ylabel('Rainfall (mm)')
plt.xlabel('Date')
plt.show()

plt.figure(figsize=(14,5))
plt.plot(daily_data['Humidity (%)'])
plt.title('Daily Humidity')
plt.ylabel('Humidity (%)')
plt.xlabel('Date')
plt.show()

# %%
monthly_data[['Air Temp (degrees C)', 'Humidity (%)', 'MSLP (hPa)']].plot(
    figsize=(14,6), title='Monthly Climate Variables'
)
plt.ylabel('Value')
plt.show()

monthly_data['Rainfall since 9 am (mm)'].plot(
    figsize=(14,5), title='Monthly Total Rainfall'
)
plt.ylabel('Rainfall (mm)')
plt.show()

# %%
wind_cols = [c for c in monthly_data.columns if c.startswith('WindDir_')]

plt.figure(figsize=(14,8))
sns.heatmap(monthly_data[wind_cols].T, cmap='Blues')
plt.title('Monthly Wind Direction Proportions')
plt.xlabel('Month')
plt.ylabel('Wind Direction')
plt.show()

# %%
daily_data['Month'] = daily_data.index.month

plt.figure(figsize=(14,6))
sns.boxplot(data=daily_data, x='Month', y='Rainfall since 9 am (mm)')
plt.title('Seasonal Distribution of Daily Rainfall')
plt.show()

plt.figure(figsize=(14,6))
sns.boxplot(data=daily_data, x='Month', y='Air Temp (degrees C)')
plt.title('Seasonal Distribution of Daily Temperature')
plt.show()

# %%
plt.figure(figsize=(14,10))
sns.heatmap(daily_data.corr(), cmap='coolwarm', center=0)
plt.title('Correlation Heatmap of Daily Variables')
plt.show()

# %%
wind_cols = [c for c in daily_data.columns if c.startswith('WindDir_')]

corrs = daily_data[wind_cols + ['Rainfall since 9 am (mm)']].corr()['Rainfall since 9 am (mm)']

plt.figure(figsize=(10,6))
corrs[:-1].sort_values().plot(kind='barh')
plt.title('Correlation Between Wind Direction and Rainfall')
plt.xlabel('Correlation')
plt.show()
